# %%
import pandas as pd

# Load the CSV file into a DataFrame
df_house = pd.read_csv('house.csv')
# Group by the StateName column and compute the average for each of the data columns
df_state_avg = df_house.groupby('StateName').mean().drop(columns=['RegionID', 'SizeRank'])

# Reset index for better readability
df_state_avg.reset_index(inplace=True)

df_state_avg.head()
# Out:
# C:\Users\birdl\AppData\Local\Temp\ipykernel_21680\3825056407.py:6: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_state_avg = df_house.groupby('StateName').mean().drop(columns=['RegionID', 'SizeRank'])
#   StateName     2000-01-31     2000-02-29     2000-03-31     2000-04-30  \
# 0        AK  138712.193182  138986.094550  139123.205664  139385.092256
# 1        AL   94932.880976   95079.114340   95206.484859   93220.900625
# 2        AR   70133.111683   70199.862609   70324.518070   70556.639050
# 3        AZ  106917.557675  107028.382687  107222.166894  107639.683497
# 4        CA  207732.185764  208394.758226  209273.740009  211248.986090
#
#       2000-05-31     2000-06-30     2000-07-31     2000-08-31     2000-09-30  \
# ...
